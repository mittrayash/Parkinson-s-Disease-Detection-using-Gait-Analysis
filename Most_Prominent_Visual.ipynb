# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.misc import imread
import matplotlib.cbook as cbook

# %matplotlib notebook

# %%
# datafile = cbook.get_sample_data('img\left.png')
img = imread('img\left.png')
plt.imshow(img, zorder=0, extent=[-750, 50, -850, 1170])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(-500, -800, 'o')
