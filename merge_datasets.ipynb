# %%
import pandas as pd
import numpy as np
# from sklearn.preprocessing import PolynomialFeatures
from sklearn import decomposition
import os

# %%
count = 0

for name in os.listdir('CSV'):
    if 'Co' in name:
        count += 1


files = []

for name in os.listdir('CSV'):
    if 'Co' in name:
        files.append('CSV/' + name)
print(files)
i = 0
    
path = 'Combined Datasets/Co_final_half.csv'
with open(path, 'a') as outfile:
    for fname in files:
        if i < count / 2:
            with open(fname) as infile:

                if i == 0: 
                    for line in infile:
                        outfile.write(line)
                else:
                    next(infile)
                    for line in infile:
                        outfile.write(line)
                i += 1
                print('{} of {} files completed'.format(i, count/2))
# Out:
# ['CSV/GaCo01_01.csv', 'CSV/GaCo02_01.csv', 'CSV/GaCo02_02.csv', 'CSV/GaCo03_01.csv', 'CSV/GaCo03_02.csv', 'CSV/GaCo04_01.csv', 'CSV/GaCo04_02.csv', 'CSV/GaCo05_01.csv', 'CSV/GaCo05_02.csv', 'CSV/GaCo06_01.csv', 'CSV/GaCo06_02.csv', 'CSV/GaCo07_01.csv', 'CSV/GaCo07_02.csv', 'CSV/GaCo08_01.csv', 'CSV/GaCo08_02.csv', 'CSV/GaCo09_01.csv', 'CSV/GaCo09_02.csv', 'CSV/GaCo10_01.csv', 'CSV/GaCo10_02.csv', 'CSV/GaCo11_01.csv', 'CSV/GaCo12_01.csv', 'CSV/GaCo13_01.csv', 'CSV/GaCo13_02.csv', 'CSV/GaCo13_10.csv', 'CSV/GaCo14_01.csv', 'CSV/GaCo14_02.csv', 'CSV/GaCo14_10.csv', 'CSV/GaCo15_01.csv', 'CSV/GaCo15_02.csv', 'CSV/GaCo15_10.csv', 'CSV/GaCo16_01.csv', 'CSV/GaCo16_02.csv', 'CSV/GaCo16_10.csv', 'CSV/GaCo17_01.csv', 'CSV/GaCo17_02.csv', 'CSV/GaCo17_10.csv', 'CSV/GaCo22_01.csv', 'CSV/GaCo22_10.csv', 'CSV/JuCo01_01.csv', 'CSV/JuCo02_01.csv', 'CSV/JuCo03_01.csv', 'CSV/JuCo04_01.csv', 'CSV/JuCo05_01.csv', 'CSV/JuCo06_01.csv', 'CSV/JuCo07_01.csv', 'CSV/JuCo08_01.csv', 'CSV/JuCo09_01.csv', 'CSV/JuCo1
# ...

# %%
count = 0

for name in os.listdir('CSV'):
    if 'Pt' in name:
        count += 1


files = []

for name in os.listdir('CSV'):
    if 'Pt' in name:
        files.append('CSV/' + name)
print(files)
i = 0
    
path = 'Combined Datasets/Pt_final_half.csv'
with open(path, 'a') as outfile:
    for fname in files:
        if i < count / 2:
            with open(fname) as infile:

                if i == 0: 
                    for line in infile:
                        outfile.write(line)
                else:
                    next(infile)
                    for line in infile:
                        outfile.write(line)
                i += 1
                print('{} of {} files completed'.format(i, count/2))
# Out:
# ['CSV/GaPt03_01.csv', 'CSV/GaPt04_01.csv', 'CSV/GaPt05_01.csv', 'CSV/GaPt06_01.csv', 'CSV/GaPt07_01.csv', 'CSV/GaPt07_02.csv', 'CSV/GaPt08_01.csv', 'CSV/GaPt08_02.csv', 'CSV/GaPt09_01.csv', 'CSV/GaPt09_02.csv', 'CSV/GaPt12_01.csv', 'CSV/GaPt12_02.csv', 'CSV/GaPt13_01.csv', 'CSV/GaPt13_02.csv', 'CSV/GaPt13_10.csv', 'CSV/GaPt14_01.csv', 'CSV/GaPt14_02.csv', 'CSV/GaPt14_10.csv', 'CSV/GaPt15_01.csv', 'CSV/GaPt15_02.csv', 'CSV/GaPt15_10.csv', 'CSV/GaPt16_01.csv', 'CSV/GaPt16_02.csv', 'CSV/GaPt16_10.csv', 'CSV/GaPt17_01.csv', 'CSV/GaPt17_02.csv', 'CSV/GaPt17_10.csv', 'CSV/GaPt18_01.csv', 'CSV/GaPt18_02.csv', 'CSV/GaPt18_10.csv', 'CSV/GaPt19_01.csv', 'CSV/GaPt19_02.csv', 'CSV/GaPt19_10.csv', 'CSV/GaPt20_01.csv', 'CSV/GaPt20_02.csv', 'CSV/GaPt20_10.csv', 'CSV/GaPt21_01.csv', 'CSV/GaPt21_02.csv', 'CSV/GaPt21_10.csv', 'CSV/GaPt22_01.csv', 'CSV/GaPt22_02.csv', 'CSV/GaPt22_10.csv', 'CSV/GaPt23_01.csv', 'CSV/GaPt23_02.csv', 'CSV/GaPt23_10.csv', 'CSV/GaPt24_01.csv', 'CSV/GaPt24_02.csv', 'CSV/GaPt2
# ...
